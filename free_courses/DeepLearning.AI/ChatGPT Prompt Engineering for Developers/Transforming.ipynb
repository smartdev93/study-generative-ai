# %% [markdown]
# ### **Transforming**
# #### **Setup**

# %%
import os, openai
from dotenv import load_dotenv, find_dotenv
from langchain_openai import ChatOpenAI
from pprint import pprint


_ = load_dotenv(find_dotenv())
openai.api_key = os.environ['OPENAI_API_KEY']

llm_model = 'gpt-3.5-turbo'
chat = ChatOpenAI(model = llm_model)

# %% [markdown]
# #### **Translation**

# %%
prompt = f'''
Translate the following English text to Spanish: \
```Hi, I would like to order a blender```
'''

response = chat.invoke(prompt)
pprint(response.content)
# Out:
# 'Hola, me gustaría ordenar una licuadora.'

# %% [markdown]
# #### **Universal Translator**

# %%
user_messages = [
  'La performance du système est plus lente que d\'habitude.',  # System performance is slower than normal         
  'Mi monitor tiene píxeles que no se iluminan.',               # My monitor has pixels that are not lighting
  'Il mio mouse non funziona',                                  # My mouse is not working
  'Mój klawisz Ctrl jest zepsuty',                              # My keyboard has a broken control key
  '我的屏幕在闪烁'                                               # My screen is flashing
]

for issue in user_messages:
    prompt = f'Tell me what language this is: ```{issue}```'
    response = chat.invoke(prompt)
    print(f'Original message ({response.content}): {issue}')

    prompt = f'''
    Translate the following  text to English \
    and Korean: ```{issue}```
    '''
    
    response = chat.invoke(prompt)
    pprint(response.content)
    print()
# Out:
# Original message (French): La performance du système est plus lente que d'habitude.
# ('English: "The system performance is slower than usual."\n'
#  'Korean: "시스템 성능이 평소보다 느립니다."')
#
# Original message (This is written in Spanish.): Mi monitor tiene píxeles que no se iluminan.
# ('English: "My monitor has pixels that do not light up."\n'
#  'Korean: "내 모니터에는 밝지 않는 화소가 있어요."')
#
# Original message (This is Italian. It translates to "My mouse is not working" in English.): Il mio mouse non funziona
# 'English: "My mouse is not working."\n\nKorean: "내 마우스가 작동하지 않아요."'
#
# Original message (This language is Polish.): Mój klawisz Ctrl jest zepsuty
# 'English: My Ctrl key is broken\nKorean: 내 Ctrl 키가 고장 났어요.'
#
# Original message (This is Chinese.): 我的屏幕在闪烁
# 'English: "My screen is flickering"\n\nKorean: "내 화면이 깜박거립니다"'

# %% [markdown]
# #### **Tone Transformation**

# %%
prompt = f'''
Translate the following from slang to a business letter: 
'Dude, This is Joe, check out this spec on this standing lamp.'
'''

response = chat.invoke(prompt)
pprint(response.content)
# Out:
# ('Dear Mr./Ms., \n'
#  '\n'
#  'I am writing to bring to your attention a specification sheet for a standing '
#  'lamp that I believe would be of interest to you. Please let me know if you '
#  'would like me to provide more information or if you have any questions. \n'
#  '\n'
#  'Sincerely, \n'
#  'Joe')

# %% [markdown]
# #### **Format Conversion**

# %%
data_json = { 'resturant employees' :[ 
    {'name':'Shyam', 'email':'shyamjaiswal@gmail.com'},
    {'name':'Bob', 'email':'bob32@gmail.com'},
    {'name':'Jai', 'email':'jai87@gmail.com'}
]}

prompt = f'''
Translate the following python dictionary from JSON to an HTML \
table with column headers and title: {data_json}
'''

response = chat.invoke(prompt)
pprint(response.content)
# Out:
# ('<!DOCTYPE html>\n'
#  '<html>\n'
#  '<head>\n'
#  '  <title>Restaurant Employees</title>\n'
#  '</head>\n'
#  '<body>\n'
#  '\n'
#  '<h2>Restaurant Employees</h2>\n'
#  '\n'
#  '<table border="1">\n'
#  '  <tr>\n'
#  '    <th>Name</th>\n'
#  '    <th>Email</th>\n'
#  '  </tr>\n'
#  '  <tr>\n'
#  '    <td>Shyam</td>\n'
#  '    <td>shyamjaiswal@gmail.com</td>\n'
#  '  </tr>\n'
#  '  <tr>\n'
#  '    <td>Bob</td>\n'
#  '    <td>bob32@gmail.com</td>\n'
#  '  </tr>\n'
#  '  <tr>\n'
#  '    <td>Jai</td>\n'
#  '    <td>jai87@gmail.com</td>\n'
#  '  </tr>\n'
#  '</table>\n'
#  '\n'
#  '</body>\n'
#  '</html>')

# %%
from IPython.display import display, Markdown, Latex, HTML, JSON
display(HTML(response.content))
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#   <title>Restaurant Employees</title>
# </head>
# <body>
#
# <h2>Restaurant Employees</h2>
#
# <table border="1">
#   <tr>
#     <th>Name</th>
#     <th>Email</th>
#   </tr>
#   <tr>
#     <td>Shyam</td>
#     <td>shyamjaiswal@gmail.com</td>
#   </tr>
#   <tr>
#     <td>Bob</td>
#     <td>bob32@gmail.com</td>
#   </tr>
#   <tr>
#     <td>Jai</td>
#     <td>jai87@gmail.com</td>
#   </tr>
# </table>
#
# </body>
# </html>

# %% [markdown]
# #### **Spellcheck/Grammar check**
# To signal to the LLM that you want it to proofread your text, you instruct the model to 'proofread' or 'proofread and correct'.

# %%
text = [ 
  'The girl with the black and white puppies have a ball.',  # The girl has a ball.
  'Yolanda has her notebook.', # ok
  'Its going to be a long day. Does the car need it’s oil changed?',  # Homonyms
  'Their goes my freedom. There going to bring they’re suitcases.',  # Homonyms
  'Your going to need you’re notebook.',  # Homonyms
  'That medicine effects my ability to sleep. Have you heard of the butterfly affect?', # Homonyms
  'This phrase is to cherck chatGPT for speling abilitty'  # spelling
]

for t in text:
  prompt = f'''Proofread and correct the following text
  and rewrite the corrected version. If you don't find
  and errors, just say "No errors found". Don't use 
  any punctuation around the text:
  ```{t}```'''
    
  response = chat.invoke(prompt)
  pprint(response.content)
# Out:
# 'The girl with the black and white puppies has a ball.'
# 'No errors found.'
# 'No errors found.'
# ('Their goes my freedom. There going to bring they’re suitcases.\n'
#  '\n'
#  'No errors found.')
# '"No errors found"'
# 'No errors found.'
# 'No errors found'

# %%
text = f'''
Got this for my daughter for her birthday cuz she keeps taking \
mine from my room.  Yes, adults also like pandas too.  She takes \
it everywhere with her, and it's super soft and cute.  One of the \
ears is a bit lower than the other, and I don't think that was \
designed to be asymmetrical. It's a bit small for what I paid for it \
though. I think there might be other options that are bigger for \
the same price.  It arrived a day earlier than expected, so I got \
to play with it myself before I gave it to my daughter.
'''
prompt = f'proofread and correct this review: ```{text}```'

response = chat.invoke(prompt)
pprint(response.content)
# Out:
# ('Got this for my daughter for her birthday because she keeps taking mine from '
#  'my room. Yes, adults also like pandas too. She takes it everywhere with her, '
#  "and it's super soft and cute. One of the ears is a bit lower than the other, "
#  "and I don't think that was designed to be asymmetrical. It's a bit small for "
#  'what I paid for it though. I think there might be other options that are '
#  'bigger for the same price. It arrived a day earlier than expected, so I got '
#  'to play with it myself before I gave it to my daughter.')

# %%
# !pip install redlines
from redlines import Redlines

diff = Redlines(text,response.content)
display(Markdown(diff.output_markdown))
# Out:
# Requirement already satisfied: redlines in c:\users\hoang\appdata\local\programs\python\python313\lib\site-packages (0.5.2)
# Requirement already satisfied: click>=8.1.7 in c:\users\hoang\appdata\local\programs\python\python313\lib\site-packages (from redlines) (8.1.8)
# Requirement already satisfied: rich-click>=1.6.1 in c:\users\hoang\appdata\local\programs\python\python313\lib\site-packages (from redlines) (1.8.9)
# Requirement already satisfied: rich>=13.3.5 in c:\users\hoang\appdata\local\programs\python\python313\lib\site-packages (from redlines) (14.0.0)
# Requirement already satisfied: colorama in c:\users\hoang\appdata\local\programs\python\python313\lib\site-packages (from click>=8.1.7->redlines) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\hoang\appdata\local\programs\python\python313\lib\site-packages (from rich>=13.3.5->redlines) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hoang\appdata\local\programs\python\python313\lib\site-packages (from rich>=13.3.5->redlines) (2.19.1)
# Requirement already satisfied: typing_extensions>=4 in c:\users\hoang\appdata\local\programs\python\python313\lib\site-packages (from rich-click>=1.6.1->redlines) (4.13.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hoang\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.3.5->redlines) (0.1.2)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Got this for my daughter for her birthday <span style='color:red;font-weight:700;text-decoration:line-through;'>cuz </span><span style='color:green;font-weight:700;'>because </span>she keeps taking mine from my room.  Yes, adults also like pandas too.  She takes it everywhere with her, and it's super soft and cute.  One of the ears is a bit lower than the other, and I don't think that was designed to be asymmetrical. It's a bit small for what I paid for it though. I think there might be other options that are bigger for the same price.  It arrived a day earlier than expected, so I got to play with it myself before I gave it to my daughter.

# %%
prompt = f'''
proofread and correct this review. Make it more compelling. 
Ensure it follows APA style guide and targets an advanced reader. 
Output in markdown format.
Text: ```{text}```
'''

response = chat.invoke(prompt)
display(Markdown(response.content))
# Out:
# I purchased this adorable panda plush for my daughter's birthday to stop her from constantly taking mine from my room. Despite being an adult, I couldn't resist the charm of this soft and cute panda. While my daughter absolutely adores it and takes it everywhere with her, I couldn't help but notice a slight asymmetry in the ears. Additionally, I found the size to be a bit small for the price I paid. However, the early arrival of the product allowed me to enjoy it before gifting it to my daughter. For the same price, I believe there may be larger options available. Overall, this panda plush is sure to be a hit with any panda lover, young or old.
